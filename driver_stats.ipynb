# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt # Needed to display the plots
from datetime import datetime, timedelta

# %%
class OpenF1Request:
    base_url = 'https://api.openf1.org/'
    api_version = 'v1'
    open_f1_api_url = base_url + api_version

    def __init__(self,
